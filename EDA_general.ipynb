# %% [markdown]
# <a href="https://colab.research.google.com/github/pysaurav/ML-Track/blob/master/EDA_general.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EDA is an approach to derive the descriptive and graphical summary of data. It involves examiming the data as they are without making any assumptions.
#
# Purpose of EDA:
#
# * Check for missing data and other mistakes.
# * Gain maximum insight into the data set and its underlying structure.
# * Uncover a parsimonious model, one which explains the data with a minimum number of predictor variables.
# * Check assumptions associated with any model fitting or hypothesis test.
# * Create a list of outliers or other anomalies.
# * Find parameter estimates and their associated confidence intervals or margins of error.
# * Identify the most influential variables.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#setting default visualization parameters
# plt.rcParams['figure.figsize'] = (4, 2)
# plt.rcParams['figure.dpi'] = 150 
sns.set()

# %% [markdown]
# #Importing Different File types

# %% [markdown]
# ## Importing a json file

# %%
import pandas as pd
df_json = pd.read_json("https://data.nasa.gov/resource/r588-f7pr.json")
df_json.head()
# Out:
#                                      sample_material  ... cure
# 0  "V" MATERIAL IN CLICKBOND CB4023V, GLASS/PEI -...  ...  NaN
# 1  "VC" MATERIAL IN CLICKBOND CB9257VC, CARBON FI...  ...  NaN
# 2             0.5 MIL KAPTON KEVLAR, SHELDAHL 177544  ...  NaN
# 3                                    0667 BLACK EPDM  ...  NaN
# 4                                1 INCH COPPER TAPE   ...  NaN
#
# [5 rows x 10 columns]

# %% [markdown]
# ## Importing a npz file

# %%
# !wget https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
datasets = np.load("mnist.npz")
df_npz = pd.DataFrame(datasets)
df_npz
# Out:
# --2020-05-08 12:19:34--  https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.203.128, 2607:f8b0:400c:c12::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.203.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11490434 (11M) [application/octet-stream]
# Saving to: ‘mnist.npz’
#
# mnist.npz           100%[===================>]  10.96M  --.-KB/s    in 0.1s
#
# 2020-05-08 12:19:34 (90.1 MB/s) - ‘mnist.npz’ saved [11490434/11490434]
#          0
# 0   x_test
# 1  x_train
# 2  y_train
# 3   y_test

# %% [markdown]
# ##Importing from HTML

# %%
url = "http://en.wikipedia.org/wiki/Twitter"
tables = pd.read_html(url)
print(len(tables))
followers_table = pd.read_html(url, match = "Followers")
followers_table[0]
# Out:
# 15
#    Rank  Change (monthly)  ...                    Activity Country
# 0     1               NaN  ...       Former U.S. president     USA
# 1     2               NaN  ...                    Musician     CAN
# 2     3               NaN  ...                    Musician     USA
# 3     4               NaN  ...  Musician and businesswoman     BAR
# 4     5               NaN  ...                    Musician     USA
# 5     6               NaN  ...                  Footballer     POR
# 6     7               NaN  ...        Musician and actress     USA
# 7     8               NaN  ...                    Comedian     USA
# 8     9               NaN  ...      Current U.S. president     USA
# 9    10               NaN  ...       Online video platform     USA
#
# [10 rows x 7 columns]

# %% [markdown]
# ## Importing a pdf file

# %%
# !pip install tabula-py

import tabula
df2 = tabula.read_pdf("https://github.com/tabulapdf/tabula-java/raw/master/src/test/resources/technology/tabula/arabic.pdf",pages = "all")
df2
# Out:
# ...
# [  اسمي سلطانمرحباً\rمن اين انت؟انا من ولاية كارولينا الشمال\r1234عندي 47 قطط\rاسمي Jeremy في الانجليزيةهل انت شباك؟\rJeremy is جرمي in Arabic                 Unnamed: 0
#  0                                             مرحباً                                                                                                          اسمي سلطان
#  1                       انا من ولاية كارولينا الشمال                                                                                                         من اين انت؟
#  2                                               1234                                                                                                         عندي 47 قطط
#  3                                       هل انت شباك؟                                                                                           اسمي Jeremy في الانجليزية
# ...

# %% [markdown]
# ## Including from google drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv("/content/drive/My Drive/Datasets/googleplaystore.csv")

# %% [markdown]
# #DataFrame Preview

# %%
df.head()
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
df.tail(5)
# Out:
#                                                  App  ...         Android Ver
# 10836                               Sya9a Maroc - FR  ...          4.1 and up
# 10837               Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                         Parkinson Exercices FR  ...          2.2 and up
# 10839                  The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [5 rows x 13 columns]

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# #Features Preview

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# import pandas_profiling
# pandas_profiling.ProfileReport(df)
# df['Reviews']=df['Reviews'].astype(float)

# %%
df.describe()
# df.describe(include=['O'])
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# #DataFrame Basic Operations

# %%
df_test = df.copy()
df_test
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# ...

# %%
###Rename Column
map_columns = {'App':'AppName', 'Android Ver':'AndroidVersion'}
df_test = df_test.rename(map_columns, axis = 'columns')
print("renamed",df_test.columns)
df_test.columns = df_test.columns.str.lower()
print("lowercase", df_test.columns)
# Out:
# renamed Index(['AppName', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'AndroidVersion'],
#       dtype='object')
# lowercase Index(['appname', 'category', 'rating', 'reviews', 'size', 'installs', 'type',
#        'price', 'content rating', 'genres', 'last updated', 'current ver',
#        'androidversion'],
#       dtype='object')

# %%
df_test[(df_test['rating'] ==5) & (df_test['category']=='MEDICAL')]
# Out:
#                                                 appname  ... androidversion
# 2262           Super Hearing Secret Voices Recorder PRO  ...     4.1 and up
# 2271                                     FHR 5-Tier 2.0  ...     4.0 and up
# 2427                                       Sway Medical  ...     5.0 and up
# 2445                                     Labs on Demand  ...     4.2 and up
# 2448         Dermatology Atlas (Colored & Illustrative)  ...     4.1 and up
# 2450                                    Tablet Reminder  ...     4.1 and up
# 2452                                   Galaxies of Hope  ...     4.1 and up
# 2454                                KBA-EZ Health Guide  ...   4.0.3 and up
# 2455                                       FoothillsVet  ...   4.0.3 and up
# 2457                                      PrimeDelivery  ...     4.1 and up
# 2458                                    You're an Anime  ...     5.0 and up
# ...

# %%
df_test[df_test.appname.isin(['LinkedIn', 'Twitter'])]
# Out:
#        appname            category  ...         current ver      androidversion
# 2582  LinkedIn              SOCIAL  ...             4.1.202          5.0 and up
# 2621  LinkedIn              SOCIAL  ...             4.1.202          5.0 and up
# 3739   Twitter  NEWS_AND_MAGAZINES  ...  Varies with device  Varies with device
# 3796   Twitter  NEWS_AND_MAGAZINES  ...  Varies with device  Varies with device
# 4115   Twitter  NEWS_AND_MAGAZINES  ...  Varies with device  Varies with device
#
# [5 rows x 13 columns]

# %%
df_test[["last_updated_date","last_updated_year"]] = df_test["last updated"].str.split(',',expand = True)
df_test.head()
# Out:
#                                              appname  ... last_updated_year
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...              2018
# 1                                Coloring book moana  ...              2018
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...              2018
# 3                              Sketch - Draw & Paint  ...              2018
# 4              Pixel Draw - Number Art Coloring Book  ...              2018
#
# [5 rows x 15 columns]

# %%
###Converting continuous column to categorical
df_test['rating_category'] = pd.cut(df_test['rating'], bins=[0, 3, 4, 5], labels=['normal', 'average', 'great'])
df_test.head()
# Out:
#                                              appname  ... rating_category
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...           great
# 1                                Coloring book moana  ...         average
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...           great
# 3                              Sketch - Draw & Paint  ...           great
# 4              Pixel Draw - Number Art Coloring Book  ...           great
#
# [5 rows x 16 columns]

# %% [markdown]
# #Data Cleaning

# %%
df["Reviews"] = df["Reviews"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-191-273956c73c29> in <module>()
# ----> 1 df["Reviews"] = df["Reviews"].astype(int)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
#Since there is a value with '3.0M' which cant be converted into string and more likely seems a outlier. Lets find it and remove it 
df[df["Reviews"].str.contains('M')]
# Out:
#                                            App Category  ...  Current Ver Android Ver
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9  ...   4.0 and up         NaN
#
# [1 rows x 13 columns]

# %%
df.drop(df.index[10472],inplace=True)
df['Reviews']=df['Reviews'].astype(int)
df.describe()
# Out:
#             Rating       Reviews
# count  9366.000000  1.084000e+04
# mean      4.191757  4.441529e+05
# std       0.515219  2.927761e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.477550e+04
# max       5.000000  7.815831e+07

# %%
df[df["Type"].isna()==True]
# Out:
#                             App  ...         Android Ver
# 9148  Command & Conquer: Rivals  ...  Varies with device
#
# [1 rows x 13 columns]

# %%
# Formattings
df['Type'].fillna('Free',inplace=True)
df['Current Ver']=df['Current Ver'].fillna(value=4)
df['Installs'] = df['Installs'].map(lambda x: x.rstrip('+'))
df['Installs']  = df['Installs'] .str.replace(',', '')
df['Installs'] =df['Installs'] .astype(int)

# %%
df.describe()
# Out:
#             Rating       Reviews      Installs
# count  9366.000000  1.084000e+04  1.084000e+04
# mean      4.191757  4.441529e+05  1.546434e+07
# std       0.515219  2.927761e+06  8.502936e+07
# min       1.000000  0.000000e+00  0.000000e+00
# 25%       4.000000  3.800000e+01  1.000000e+03
# 50%       4.300000  2.094000e+03  1.000000e+05
# 75%       4.500000  5.477550e+04  5.000000e+06
# max       5.000000  7.815831e+07  1.000000e+09

# %% [markdown]
# #Visualizations

# %% [markdown]
# Nominal Categorical Data can be presented as Pie, bar, stacked plot and so on
# Ordinal Categorical Data as bar plots
# Two continuous data - Scatter Plot
# One Continuous and One Categorical - Box Plot

# %% [markdown]
# ##Pie-Plot (Nominal Categorical Data); Univariate

# %%
labels=list(df['Category'].value_counts().index[:7])
values=df['Category'].value_counts().values[:7].tolist()
labels.append('Others')
values.extend([(sum(df['Category'].value_counts().values[7:]))])

plt.figure(figsize=(5,5))
plt.pie(values,labels=labels,autopct='%1.1f%%')
plt.title('Category',color='black',fontsize=10)
plt.show()

# %% [markdown]
# ##Bar-Plot (Nominal and Ordinal Features)

# %%
def univariateAnalysis(featureName):
    sliced =pd.DataFrame({'Frequency':featureName.value_counts()})    
    x=sliced.index.values
    y=sliced.Frequency.values
    plt.figure(figsize=(8,8))
    ax=sns.barplot(x,y,palette="CMRmap")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    return 0
univariateAnalysis(df["Type"])
# Out:
# 0

# %%
univariateAnalysis( df['Content Rating'])
# Out:
# 0

# %%
univariateAnalysis( df['Android Ver'])
# Out:
# 0

# %%
univariateAnalysis(df['Installs'])
# Out:
# 0

# %%
univariateAnalysis(df['Rating'])
# Out:
# 0

# %% [markdown]
# ##Histogram

# %%
# sns.set()
plt.figure(figsize=(10,5))
sns.distplot(df['Rating'],color='b')
plt.title("Rating Distrubition").set_color(label_colour)
plt.show()

# %%
df.Rating.plot(kind = 'hist',bins = 50,figsize = (10,5))
plt.show()

# %% [markdown]
# ##Bivariate Analysis

# %%
def barplotBivariate(x,y):
    plt.figure(figsize=(10,8))
    plt.xticks(rotation=90)
    #plotting
    sns.barplot(x,y,palette="CMRmap")
barplotBivariate(df['Content Rating'],df['Installs'])

# %%
barplotBivariate(df['Category'],df['Installs'])

# %%
#boxplot plot installs/rates
ax = plt.figure(figsize=(10,5))
sns.set()
sns.boxplot(x="Installs", y="Rating", data=df)
plt.title("Installs/Rating")
# plt.tick_params(axis='x', colors=label_colour)
# plt.tick_params(axis='y', colors=label_colour)
plt.xticks(rotation=80)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(8,7))
ax = sns.heatmap(df[["Reviews","Rating","Installs"]].corr(), annot=True,linewidths=.5,fmt='.1f')
plt.show()

# %%
sns.pairplot(df.select_dtypes(include=np.number))
plt.show()

# %%
columns = df.select_dtypes(include=np.number).columns
figure = plt.figure(figsize=(10, 5))
figure.add_subplot(1, len(columns), 1)
for index, col in enumerate(columns):
    if index > 0:
        figure.add_subplot(1, len(columns), index + 1)
    sns.boxplot(y=col, data=df, boxprops={'facecolor': 'None'})
figure.tight_layout()
plt.show()

# %%
##ScatterPlot

# %%
sns.scatterplot(x="Reviews", y="Rating", data=df)

# %%
from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS

stopwords = set(STOPWORDS)

wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(df['Category']))

print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# fig.savefig("word1.png", dpi=900)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df.Category.values
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
